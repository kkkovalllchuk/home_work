# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_table('C:/Users/Дарина/Desktop/DS4.txt',delim_whitespace=True)
my_dpi = 120
plt.figure(figsize=(960/my_dpi, 540/my_dpi), dpi=my_dpi)
plt.scatter(dataset.iloc[:,1],dataset.iloc[:,0])
plt.show()
